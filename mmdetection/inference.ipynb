# %%
import mmcv
from mmcv import Config
from mmdet.datasets import build_dataloader, build_dataset, replace_ImageToTensor
from mmdet.models import build_detector
from mmdet.apis import inference_detector,show_result_pyplot,init_detector
from mmcv.runner import load_checkpoint
import os
from mmcv.parallel import MMDataParallel
# %matplotlib inline

# %%
classes = ("pill",)
config_file = 'configs/_sangyoon_/yolact_r50_1x8_coco.py'
#epoch = 'latest'
checkpoint_path = os.path.join('path/of/pth')

# %%
model = init_detector(config_file, checkpoint_path, device='cuda:0')
# Out:
# load checkpoint from local path: work_dirs/yolact_r50_1x8_coco/latest.pth

# %%
img ='test_image.jpg'

# %%
results = inference_detector(model, img)
# Out:
# /opt/ml/final-project-level3-cv-16/mmdetection/mmdet/datasets/utils.py:66: UserWarning: "ImageToTensor" pipeline is replaced by "DefaultFormatBundle" for batch inference. It is recommended to manually replace it in the test data pipeline in your config file.
#   warnings.warn(

# %%
show_result_pyplot(model, img, results)
